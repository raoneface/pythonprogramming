# %% [markdown]
# ## Measure of dispersion

# %% [markdown]
#  Variance and standerd deviation

# %%
# population variance and sample variance0

# %%
ages_lst = [23,43,23,56,74,32,68,98,45,32]

# %%
import numpy as np

# %%
## mean
np.mean(ages_lst)
# Out:
# np.float64(49.4)

# %%
## variance
np.var(ages_lst)
# Out:
# np.float64(541.64)

# %%
## standerd deviation
np.std(ages_lst)
# Out:
# np.float64(23.273160507331188)

# %%
import seaborn as sns 
sns.histplot(ages_lst,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
## 
import pandas as pd

# %%
data = [[]]
