# %%
l = [2,3,4,5,6]

# %%
def test(l):
    l1 = []
    for i in l:
        l1.append(i**2)
    return l1

# %%
test(l)
# Out:
# [4, 9, 16, 25, 36]

# %%
def sq(x):
    return x**2

# %%
list(map(sq , l))
# Out:
# [4, 9, 16, 25, 36]
