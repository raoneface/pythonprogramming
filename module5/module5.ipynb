# %%
# python suport oops and moduler coding.
# declaring variable
# python self type 
sudha = 20

# %%
# s is string type 
s ='shubham'
print(s[0:7])
print(type(s))

# s store float type
s = 322.34
print(type(s))

# double quotes and single quotes doent matter but one at a time

# s is bool type
s = True
print(s)
print(type(s))

q = False

# it will give output 1
print(s+q)

# it will give output 0
print(False*False)

# it will give error
#print(True/False)

# it will give output 0
print(True * False)

# it will give type complex
v = 2 + 3j
print(v)
print(type(v))

print(v.imag)
print(v.real)

print("hello world")
# Out:
# shubham
# <class 'str'>
# <class 'float'>
# True
# <class 'bool'>
# 1
# 0
# 0
# (2+3j)
# <class 'complex'>
# 3.0
# 2.0
# hello world

# %%
# accessing index from start from 0 and till the last element but jump is 2
# basically it is slicing  concept
s[::2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # accessing index from start from 0 and till the last element but jump is 2
#       2 # basically it is slicing  concept
# ----> 3 s[::2]
#
# TypeError: 'bool' object is not subscriptable

# %%
# again s is str type variable
s='pwskills'
type(s)
# Out:
# str

# %%
# accesing index from last element  to first element 
s[::-1]
# Out:
# 'sllikswp'

# %%
# slicing element from index 2 to 7 but order is right to left that why it gives no element inside this range
s[2:7:-1]
# Out:
# ''

# %%
#  it will give also nothing why because slising is start from seven index and try find next element which is next 9th index elemet because itrater is + forward direction
s[8:0]
# Out:
# ''

# %%
## it will give elemet starting from 8th positions  and it will print upto index 1
s[8:0:-1]
# Out:
# 'slliksw'

# %%
s[7::-1]
# Out:
# 'sllikswp'

# %%
s[-2:-8:1]
# Out:
# ''

# %%
s[-2:-8:-1]
# Out:
# 'lliksw'

# %%
s[::]
# Out:
# 'pwskills'

# %%
s[:-90:1]
# Out:
# ''

# %%
s[-90::1]
# Out:
# 'pwskills'

# %%
s="My name is shubham kumar"

# %%
# it will gives the length of function
len(s)
# Out:
# 24

# %%
print(s.find('shubham'))
print(s.find('z'))
# Out:
# 11
# -1

# %%
s.count("m")
# Out:
# 3

# %%
s.upper()
# Out:
# 'MY NAME IS SHUBHAM KUMAR'

# %%
s.lower()
# Out:
# 'my name is shubham kumar'

# %%
s.title()
# Out:
# 'My Name Is Shubham Kumar'

# %%
s + " kumar"
# Out:
# 'My name is shubham kumar kumar'

# %%
s *3
# Out:
# 'My name is shubham kumarMy name is shubham kumarMy name is shubham kumar'

# %%
s + str(2334)
# Out:
# 'My name is shubham kumar2334'

# %%
s3="""jaldi khatam karo bhai
kya kar rahe ho abhi tak python me hi atke ho bhao"""

# %%
s3
# Out:
# 'jaldi khatam karo bhai\nkya kar rahe ho abhi tak python me hi atke ho bhao'
