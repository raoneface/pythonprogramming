# %%
import numpy as np

# %%
l = [1,2,3,4]

# %%
ar = np.array(l)
ar
# Out:
# array([1, 2, 3, 4])

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
np.asanyarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
b = np.matrix(l)

# %%
b
# Out:
# matrix([[1, 2, 3, 4]])

# %%
np.asanyarray(b)
# Out:
# matrix([[1, 2, 3, 4]])

# %%
a = np.array(l)

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
## swallow copy 
c = a
# Out:
# np.int64(66)

# %%
c[0]
# Out:
# np.int64(66)

# %%
c[0]=1

# %%
c[0]
# Out:
# np.int64(1)

# %%
a[0]
# Out:
# np.int64(1)

# %%
## creating new copy on new location
d = np.copy(a)
