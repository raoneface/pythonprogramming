# %%
import threading

# %%
def test(id):
    print("program start %d ",id)

# %%
test(45)
# Out:
# program start %d  45

# %%
thread = [threading.Thread(target=test, args=(i,)) for i in range(10)]

# %%
for i in thread :
    t.start()
