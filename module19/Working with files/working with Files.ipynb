# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is E826-933E
#
#  Directory of d:\pythonprogramming\module19\Working with files
#
# 02/06/2026  12:31 PM    <DIR>          .
# 02/06/2026  12:30 PM    <DIR>          ..
# 02/06/2026  12:31 PM               523 working with Files.ipynb
#                1 File(s)            523 bytes
#                2 Dir(s)  242,215,575,552 bytes free

# %%
pwd
# Out:
# 'd:\\pythonprogramming\\module19\\Working with files'

# %%
f = open("test.txt",'w') ## w mode will truncate everyrthing then write any thing

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is E826-933E
#
#  Directory of d:\pythonprogramming\module19\Working with files
#
# 02/06/2026  12:32 PM    <DIR>          .
# 02/06/2026  12:30 PM    <DIR>          ..
# 02/06/2026  12:32 PM                 0 test.txt
# 02/06/2026  12:32 PM             1,837 working with Files.ipynb
#                2 File(s)          1,837 bytes
#                2 Dir(s)  242,215,571,456 bytes free

# %%
f.write("this is my first file to write")
# Out:
# 30

# %%
f.close()

# %%
f = open("test.txt",'w')

# %%
f.write("this is my file")
# Out:
# 15

# %%
f.close()

# %%
f = open("test.txt" ,'a')    
## a mode will append only . a mode does not truncate the data

# %%
f.write(" i am going to sachool")
# Out:
# 22

# %%
f.close()

# %%
## r mode open only in read mode 
data = open("test.txt" , 'r')

# %%
## it will read data 
data.read()
# Out:
# 'this is my file i am going to sachool i am going to sachool'

# %%
## seek is use to start positioning at any point 
data.seek(0)
data.readline()
# Out:
# 'this is my file i am going to sachool i am going to sachool'

# %%
data1 = open("test.txt" ,'r')
data1.seek(0)
for i in data1:
    print(i)
# Out:
# this is my file i am going to sachool i am going to sachool

# %%
## os module
import os

# %%
## it will give the size in byte
os.path.getsize("test.txt")
# Out:
# 59

# %%
import os

if os.path.exists("test.txt"):
    os.remove("test.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[37], line 4
#       1 import os
#       3 if os.path.exists("test.txt"):
# ----> 4     os.remove("test.txt")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'test.txt'

# %%
# Out:
# {'name': 'python.exe', 'pid': 24368}

# %%
f = open("test1.txt",'w')

# %%
f.write("i am a software developer")
f.close()

# %%
os.remove("test1.txt")

# %%
## it will rename the file name
os.rename("test1.txt" ,'newtest.txt')

# %%
import shutil

# %%
## it will craete a another copy file with copy_new.txt
shutil.copy("newtest.txt","copy_new.txt")
# Out:
# 'copy_new.txt'

# %%
with open("test.txt" ,'r') as f:
    print(f.read())
# Out:
# this is my file i am going to sachool i am going to sachool
