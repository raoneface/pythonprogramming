# %% [markdown]
# # Flask introduction
# Flask is a micro web framework written in Python. It is designed to be lightweight and easy to use, making it a popular choice for building web applications. Flask provides the necessary tools and libraries to create web applications, but it does not include many of the features that are commonly found in larger frameworks, such as database integration or form handling. This allows developers to have more control over their application and choose the components they need. Flask is often used for small to medium-sized projects, but it can also be used for larger applications with the help of extensions.
# ## Installation To install Flask, you can use pip, which is the package installer for Python. Open your terminal and run the following command:
#
# ```pip install Flask
# ```This will install Flask and its dependencies. Once the installation is complete, you can start building your Flask application.
# ## Creating a Flask Application To create a Flask application, you need to create a Python file (e.g., app.py) and import the Flask class from the flask module. Then, you can create an instance of the Flask class and define your routes. Here is a simple example:
#
# ```pythonfrom flask import Flask
# app = Flask(__name__)
# @app.route('/')
# def hello():
#     return 'Hello, World!'
# if __name__ == '__main__':
#     app.run(debug=True)
# ```In this example, we import the Flask class and create an instance of it called `app`. We then define a route for the root URL (`/`) and a function that returns a simple message. Finally, we run the application in debug mode, which allows for easier development and debugging.
# ## Running the Application To run the Flask application, you can use the command line. Navigate to the directory where your app.py file is located and run the following command:
#
# ```python app.py
# ```This will start the Flask development server, and you should see output indicating that the server is running. You can then open your web browser and navigate to `http://localhost:5000/` to see the "Hello, World!" message displayed on the page.
# ## Conclusion Flask is a powerful and flexible web framework that allows developers to quickly build web applications. With its simplicity and ease of use, Flask is a great choice for both beginners and experienced developers looking to create web applications in Python.

# %%
# %pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello , World</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

## what is __name__ and __main__ in python
# __name__ is a special variable in python that is used to determine the name of the module.
#  It is set to "__main__" when the module is run as the main program. 
# If the module is imported, __name__ is set to the name of the module.
# __main__ is the name of the top-level script environment.
#  It is the name of the module that is being run as the main program. 
# When a module is run as the main program, __name__ is set to "__main__".
#  This allows us to check if a module is being run as the main program or if it is being imported as a module in another script.
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.0.107:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [07/Feb/2026 17:21:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2026 17:21:07] "GET /favicon.ico HTTP/1.1" 404 -
# 192.168.0.107 - - [07/Feb/2026 17:21:11] code 400, message Bad request version ('T\x02²Ç¤UÁ$j9Y<m»pq!u\x12J´3µX?"\x88;6\x07ÎÚ)Ù97O`vfô´\x16¸/rÔÅâ,e\x9e')
# ...
