# %%
l = [1,2,3,4,45,5]

# %%
l1 = []
for i in l:
    l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
[i**2 for i in l]
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
[i for i in l if i%2==0]
# Out:
# [2, 4]

# %%
l1 = ["hellow" ,"Shubham","kumar","sourabh" ,"kumar"]

# %%
l2 = [i.upper() for i in l1 ]

# %%
l2
# Out:
# ['HELLOW', 'SHUBHAM', 'KUMAR', 'SOURABH', 'KUMAR']

# %%
## dictionary comprehension

# %%
list((i**2 for i in l))
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
d = {"key1": 1 ,"key2":2,"key3":3 , "key4":4}
