# %%
# declaring a list
# list can contain multiple items
l = [1,345,45,"sudh",True,5+7j, 345.456]

# %%
# type of variable
type(l)
# Out:
# list

# %%
## accesing element with index
l[0]
# Out:
# 1

# %%
# slicing from 0 to 3 index
l[0:3]
# Out:
# [1, 345, 45]

# %%
## it will give element at index last one 
l[-1]
# Out:
# 345.456

# %%
## it will give all the element from last to first
l[::-1]
# Out:
# [345.456, (5+7j), True, 'sudh', 45, 345, 1]

# %%
## it will give element on even index from starting to end 
l[::2]
# Out:
# [1, 45, True, 345.456]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
s = "pwskills"
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 s = "pwskills"
# ----> 2 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
## here s is converting into a list then add with another list
list(s) + l
# Out:
# ['p',
#  'w',
#  's',
#  'k',
#  'i',
#  'l',
#  'l',
#  's',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
## we need only 'su' 
l[3][0:2]
# Out:
# 'su'

# %%
# type of su
type(l[3][0:2])
# Out:
# str

# %%
## we conver bool into str then we slice 
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 l + 5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1 = [3,4,5]

# %%
## we can add a list with a list
l + l1
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 3, 4, 5]

# %%
## if we ,ultiply a list with a numbebr it will give the same list multiple that number of times
l1 * 3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
## it will give the length of list
len(l)
# Out:
# 7

# %%
## it will append in list at last
l.append(5)

# %%
l.append(s)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, 'pwskills']

# %%
l.remove("pwskills")

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5]

# %%
l1 = [3,4,5]

# %%
l.append(l1)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, [3, 4, 5]]

# %%
l[-1][1]
# Out:
# 4

# %%
## extend function
## data should be itrable that means data inside data then it will extend 
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 ## extend function
#       2 ## data should be itrable that means data inside data then it will extend
# ----> 3 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, [3, 4, 5], 's', 'u', 'd', 'h']

# %%
## it will unwrap the list then insert into list
l.extend([3,4,5])

# %%
## insert function
## it insert data should be data at a specific position
l1.insert(1,"sudh")

# %%
l1
# Out:
# [3, 'sudh', 4, 5]

# %%
l1.insert(2,[2,3,4])

# %%
l1.insert(-1,45)

# %%
l1.insert(0,45)

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 4, 45, 5]

# %%
## deleteing data from list

# %%
## pop function 
## it will remove data from last index by default index is last
l1.pop()
# Out:
# 5

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 4, 45]

# %%
l1.pop()
# Out:
# 45

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 4]

# %%
## it remove data from 3rd index
l1.pop(3)
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [45, 3, 'sudh', 4]

# %%
## remove function
## it will remove the value 
l1.remove(3)

# %%
l1
# Out:
# [45, 'sudh', 4]

# %%
l1.remove(234)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 l1.remove(234)
#
# ValueError: list.remove(x): x not in list

# %%
## it will remove the data from list inside a list
l1[2].remove(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 2
#       1 ## it will remove the data from list inside a list
# ----> 2 l1[2].remove(3)
#
# AttributeError: 'int' object has no attribute 'remove'

# %%
## sudh se dh remove karo -> not possible
## string is a immutable object thats why it is not possible

# %%
l1 = l1[::-1]

# %%
l1
# Out:
# [4, 'sudh', 45]

# %%
l1.reverse()

# %%
## it will give permanent reverse
l1.reverse()

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l2 = [3,4,5,67,7,8,9]

# %%
## it will sort the list and permanent change in same list
l2.sort()

# %%
l2
# Out:
# [3, 4, 5, 7, 8, 9, 67]

# %%
l2
# Out:
# [3, 4, 5, 7, 8, 9, 67]

# %%
## it will sort the list and permanent change in same list
l2.sort()

# %%
l4 = ["sudh","kumar","pwskills","data science"]

# %%
l4.sort()

# %%
l4
# Out:
# ['data science', 'kumar', 'pwskills', 'sudh']

# %%
## reverse  order sorting
l4.sort(reverse=True)

# %%
l4
# Out:
# ['sudh', 'pwskills', 'kumar', 'data science']

# %%
## it will return index
l4.index("pwskills")
# Out:
# 1

# %%
## it will return frequency
l4.count("sudh")
# Out:
# 1

# %%
s = "sudh"

# %%
l5 = [3,4,5,6]

# %%
s[0]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 s[0]='a'
#
# TypeError: 'str' object does not support item assignment

# %%
l5[0]= 30

# %%
l5
# Out:
# [30, 4, 5, 6]

# %%
s = "sudh"

# %%
s
# Out:
# 'sudh'

# %%
## this is creating new object it does not mutate 
s.replace('s','a')
# Out:
# 'audh'

# %%
s
# Out:
# 'sudh'
