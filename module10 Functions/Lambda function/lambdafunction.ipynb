# %%
n = 3
p = 4

# %%
def test(n,p):
    return n**p

# %%
test(n,p)
# Out:
# 81

# %%
## this is also called lambda function
## anonymous also

a = lambda n,p :n**p

# %%
a(3,4)
# Out:
# 81

# %%
add = lambda x,y : x + y

# %%
add(4,5)
# Out:
# 9

# %%
c_to_f = lambda c : (9/5)*c + 32

# %%
c_to_f(67)
# Out:
# 152.60000000000002

# %%
finding_max = lambda x,y : x if x>y  else y

# %%
finding_max(33,77)
# Out:
# 77

# %%
s = "pwskills"

# %%
find_len = lambda s: len(s)

# %%
find_len(s)
# Out:
# 8
