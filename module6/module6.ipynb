# %%
# declaring a list
# list can contain multiple items
l = [1,345,45,"sudh",True,5+7j, 345.456]

# %%
# type of variable
type(l)
# Out:
# list

# %%
## accesing element with index
l[0]
# Out:
# 1

# %%
# slicing from 0 to 3 index
l[0:3]
# Out:
# [1, 345, 45]

# %%
l[-1]
# Out:
# 345.456

# %%
l[::-1]
# Out:
# [345.456, (5+7j), True, 'sudh', 45, 345, 1]

# %%
l[::2]
# Out:
# [1, 45, True, 345.456]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
# we can not concatenate list with a string
s = "pwskills"
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # we can not concatenate list with a string
#       2 s = "pwskills"
# ----> 3 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s) + l
# Out:
# ['p',
#  'w',
#  's',
#  'k',
#  'i',
#  'l',
#  'l',
#  's',
#  1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
## we need only 'su' 
l[3][0:2]
# Out:
# 'su'

# %%
# type of su
type(l[3][0:2])
# Out:
# str

# %%
## we conver bool into str then we slice 
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 l + 5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1 = [3,4,5]

# %%
## we can add a list with a list
l + l1
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 3, 4, 5]

# %%
## if we ,ultiply a list with a numbebr it will give the same list multiple that number of times
l1 * 3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
## it will give the length of list
len(l)
# Out:
# 7

# %%
## it will append in list at last
l.append(5)

# %%
l.append(s)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, 'pwskills', 'pwskills']

# %%
l.remove("pwskills")

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, 'pwskills']

# %%
l1 = [3,4,5]

# %%
l.append(l1)

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, 'pwskills', [3, 4, 5]]

# %%
l[-1][1]
# Out:
# 4

# %%
## extend function
## data should be itrable that means data inside data 
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 ## extend function
# ----> 2 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  'pwskills',
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h']

# %%
## it will unwrap the list then insert into list
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'sudh',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  'pwskills',
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  3,
#  4,
#  5]

# %%
l1
# Out:
# [3, 4, 5]

# %%
## insert function
## it insert data should be data at a specific position
l1.insert(1,"sudh")

# %%
l1
# Out:
# [3, 'sudh', 4, 5]

# %%
l1.insert(2,[2,3,4])

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 5]

# %%
l1.insert(-1,45)

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 45, 5]

# %%
l1.insert(0,45)

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 45, 5]

# %%
## deleteing data from list

# %%
## pop function 
## it will remove data from last index by default index is last
l1.pop()
# Out:
# 5

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], [2, 3, 4], 4, 45]

# %%
l1.pop()
# Out:
# 45

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], [2, 3, 4], 4]

# %%
## it remove data from 3rd index
l1.pop(3)
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 4]

# %%
## remove function
## it will remove the value 
l1.remove(3)

# %%
l1
# Out:
# [45, 'sudh', [2, 4], 4]

# %%
l1.remove(234)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 l1.remove(234)
#
# ValueError: list.remove(x): x not in list

# %%
## it will remove the data from list inside a list
l1[2].remove(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 2
#       1 ## it will remove the data from list inside a list
# ----> 2 l1[2].remove(3)
#
# ValueError: list.remove(x): x not in list

# %%
## sudh se dh remove karo -> not possible
## string is a immutable object thats why it is not possible

# %%
l1 = l1[::-1]

# %%
l1
# Out:
# [4, [2, 4], 'sudh', 45]

# %%
l1.reverse()

# %%
l1
# Out:
# [45, 'sudh', [2, 4], 4]

# %%
## it will give permanent reverse
l1.reverse()

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l2 = [3,4,5,67,7,8,9]

# %%
## it will sort the list and permanent change in same list
l2.sort()

# %%
l2
# Out:
# [3, 4, 5, 7, 8, 9, 67]

# %%
l4 = ["sudh","kumar","pwskills","data science"]

# %%
l4.sort()

# %%
l4
# Out:
# ['data science', 'kumar', 'pwskills', 'sudh']

# %%
## reverse  order sorting
l4.sort(reverse=True)

# %%
l4
# Out:
# ['sudh', 'pwskills', 'kumar', 'data science']

# %%
## it will return index
l4.index("pwskills")
# Out:
# 1

# %%
## it will return frequency
l4.count("sudh")
# Out:
# 1

# %%
s = "sudh"

# %%
l5 = [3,4,5,6]

# %%
s[0]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 s[0]='a'
#
# TypeError: 'str' object does not support item assignment

# %%
l5[0]= 30

# %%
l5
# Out:
# [30, 4, 5, 6]

# %%
s = "sudh"

# %%
s
# Out:
# 'sudh'

# %%
## this is creating new object it does not mutate 
s.replace('s','a')

# %%
s
# Out:
# 'sudh'

# %%
## this is tuple
t = (2,3,4,5,"sudh",45.56,False, 45+345j,[3,4,5])

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+345j), [3, 4, 5])

# %%
## 
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t[::-1]
# Out:
# ([3, 4, 5], (45+345j), False, 45.56, 'sudh', 5, 4, 3, 2)

# %%
l4
# Out:
# ['sudh', 'pwskills', 'kumar', 'data science']

# %%
l4[0]=23424

# %%
l4
# Out:
# [23424, 'pwskills', 'kumar', 'data science']

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+345j), [3, 4, 5])

# %%
t[0]
# Out:
# 2

# %%
## tuples are immutable
t[0] ="sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 t[0] ="sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count("sudh")
# Out:
# 1

# %%
t.index("sudh")
# Out:
# 4

# %%
t.index(False)
# Out:
# 6

# %%
## set
s1 = {}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3={324,456,456,"sudh",45.465,(3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), 324, 45.465, 456, 'sudh'}

# %%
s3={324,456,6678,[77,99,44]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 s3={324,456,6678,[77,99,44]}
#
# TypeError: unhashable type: 'list'

# %%
s4={222334,2234,234,234,234,"sudgh","dgfhjy"}

# %%
s4
# Out:
# {222334, 2234, 234, 'dgfhjy', 'sudgh'}

# %%
l6 = list(set(s4))

# %%
l6
# Out:
# ['sudgh', 'dgfhjy', 2234, 234, 222334]

# %%
type(l6)
# Out:
# list

# %%
s5 = {234,45,23,12,567,45,2,789}

# %%
## indexing concept gives error for set  
## indexing not allow
s5[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 s5[0]
#
# TypeError: 'set' object is not subscriptable

# %%
##### add 66 in set
s5.add(66)

# %%
s5
# Out:
# {2, 12, 23, 45, 66, 234, 567, 789}

# %%
s5
# Out:
# {2, 12, 23, 45, 66, 234, 567, 789}

# %%
## remove 45 from set
s5.remove(45)

# %%
s5
# Out:
# {2, 12, 23, 66, 234, 567, 789}
